# %% [markdown]
# # Introduction

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This document is an analysis of the search algorithms and heuristics that were used to solve the three Air cargo problems proposed for the project.
#
# The experimental settings were as follows:
#   * __search limit__: up to hardware limits, no timeout
#   * __elements tested__: all problems (3) and searches (10) available
#   * __benchnark script__: a modified run_search.py that output json files
#   * __hardware__: Processor 8 x Intel Core i7-4710Hq CPU 2.50 GHz, 16 GiB of RAM
#
# In the first part of this analysis, we will prepare the data prior to its exploration.
#
# Then, we will review the main four characteristics associated to AI search algorithms:
#   * optimality
#   * completeness
#   * time complexity
#   * space complexity
#
# Finally, we will provide an answer to suggest which algorithm should be used in the general case.

# %% [markdown]
# # Preparation

# %%
from itertools import product
from glob import iglob
import pandas as pd
import numpy as np
import json
import os
import re

# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12.0, 4.0)

# %%
# files and formats
DIR = '../data/run/'
FILES = iglob(os.path.join(DIR, '*.json'))
RES_PAT = re.compile('air_cargo_problem_(\d+)-(\w+)-(\w+)')
COLUMNS = ['problem', 'search', 'algorithm', 'heuristic', 'uninformed', 'runtime', 
           'plan_length', 'expansions', 'goal_tests', 'new_nodes', 'plan']

# problems and searches
PROBLEMS = ['1', '2', '3']

SEARCHES = [
    ["breadth_first_search", "uninformed"],
    ['breadth_first_tree_search', "uninformed"],
    ['depth_first_graph_search', "uninformed"],
    ['depth_limited_search', "uninformed"],
    ['uniform_cost_search', "uninformed"],
    ['recursive_best_first_search', 'h_1'],
    ['greedy_best_first_graph_search', 'h_1'],
    ['astar_search', 'h_1'],
    ['astar_search', 'h_ignore_preconditions'],
    ['astar_search', 'h_pg_levelsum'],
]

def sname(algo, heur):
    """Format an algorithm and heuristic to a search name."""
    return "{} - {}".format(algo, heur).replace('_', ' ')


RESULTS = list()

# import results
for f in FILES:
    file, ext = os.path.splitext(f) 
    filename = os.path.basename(file)
    match = RES_PAT.match(filename)
    
    if match is None:
        raise ValueError("Match failed for: {}".format(filename))
        
    prob, algo, heur = match.groups()
    uninformed = heur == 'uninformed'
    
    with open(f, 'r') as r:
        res = json.load(r)
    
    res['problem'] = prob
    res['algorithm'] = algo
    res['heuristic'] = heur
    res['uninformed'] = uninformed
    res['search'] = sname(algo, heur)
    
    RESULTS.append(res)

# create a dataframe from results
df = pd.DataFrame(RESULTS, columns=COLUMNS) \
       .sort_values(['problem', 'runtime'])

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Overview

# %%
df.drop(['search', 'plan'], axis=1)
# Out:
#    problem                       algorithm               heuristic uninformed  \
# 10       1  greedy_best_first_graph_search                     h_1      False
# 1        1        depth_first_graph_search              uninformed       True
# 15       1            breadth_first_search              uninformed       True
# 13       1             uniform_cost_search              uninformed       True
# 17       1                    astar_search  h_ignore_preconditions      False
# 12       1                    astar_search                     h_1      False
# 9        1            depth_limited_search              uninformed       True
# 2        1       breadth_first_tree_search              uninformed       True
# 22       1     recursive_best_first_search                     h_1      False
# 7        1                    astar_search           h_pg_levelsum      False
# 8        2  greedy_best_first_graph_search                     h_1      False
# 18       2        depth_first_graph_search              uninformed       True
# 14       2            breadth_first_search              uninformed       True
# 6        2                    astar_search  h_ignore_preconditions      False
# 20       2             uniform_cost_search              uninformed       True
# 21       2                    astar_search                     h_1      False
# 11       2            depth_limited_search              uninformed       True
# 5        3        depth_first_graph_search              uninformed       True
# 4        3            breadth_first_search              uninformed       True
# 16       3                    astar_search  h_ignore_preconditions      False
# 0        3  greedy_best_first_graph_search                     h_1      False
# 19       3                    astar_search                     h_1      False
# 3        3             uniform_cost_search              uninformed       True
#
#         runtime  plan_length  expansions  goal_tests  new_nodes
# 10     0.010160            6           7           9         28
# 1      0.021924           20          21          22         84
# 15     0.024268            6          43          56        180
# 13     0.049170            6          55          57        224
# 17     0.076575            6          41          43        170
# 12     0.118958            6          55          57        224
# 9      0.146723           50         101         271        414
# 2      1.592876            6        1458        1459       5960
# 22     4.504784            6        4229        4230      17023
# 7     10.033305            6          18          20         77
# 8      0.130309           15          35          37        299
# 18     5.494803          619         624         625       5602
# 14    21.990256            9        3343        4609      30509
# 6     26.639975            9        1506        1508      13820
# 20    84.186726            9        4853        4855      44041
# 21    86.061412            9        4853        4855      44041
# 11  1656.404348           50      222719     2053741    2054119
# 5      2.490629          392         408         409       3364
# 4    213.483141           12       14663       18098     129631
# 16   218.743101           12        5118        5120      45650
# 0    258.498690           24        4587        4589      40379
# 19   939.075264           12       18236       18238     159726
# 3    966.414331           12       18236       18238     159726

# %% [markdown]
# ## Completeness

# %%
def is_complete(df, p, a, h):
    return ((df['problem'] == p) & (df['algorithm'] == a) & (df['heuristic'] == h)).any()


COMPLETES = list()

for p, s in product(PROBLEMS, SEARCHES):
    a, h = s
    
    doc = {
        'problem': p,
        'search': sname(a, h),
        'complete': 1 if is_complete(df, p, a, h) else 0
    }
    
    COMPLETES.append(doc)
    
complete = pd.DataFrame(COMPLETES, columns=['problem', 'search', 'complete']) \
             .sort_values('problem')

# %%
complete
# Out:
#    problem                                  search  complete
# 0        1       breadth first search - uninformed         1
# 1        1  breadth first tree search - uninformed         1
# 2        1   depth first graph search - uninformed         1
# 3        1       depth limited search - uninformed         1
# 4        1        uniform cost search - uninformed         1
# 5        1       recursive best first search - h 1         1
# 6        1    greedy best first graph search - h 1         1
# 7        1                      astar search - h 1         1
# 8        1   astar search - h ignore preconditions         1
# 9        1            astar search - h pg levelsum         1
# 19       2            astar search - h pg levelsum         0
# 18       2   astar search - h ignore preconditions         1
# 17       2                      astar search - h 1         1
# 16       2    greedy best first graph search - h 1         1
# 15       2       recursive best first search - h 1         0
# 14       2        uniform cost search - uninformed         1
# 13       2       depth limited search - uninformed         1
# 12       2   depth first graph search - uninformed         1
# 11       2  breadth first tree search - uninformed         0
# 10       2       breadth first search - uninformed         1
# 20       3       breadth first search - uninformed         1
# 21       3  breadth first tree search - uninformed         0
# 22       3   depth first graph search - uninformed         1
# 23       3       depth limited search - uninformed         0
# 24       3        uniform cost search - uninformed         1
# 25       3       recursive best first search - h 1         0
# 26       3    greedy best first graph search - h 1         1
# 27       3                      astar search - h 1         1
# 28       3   astar search - h ignore preconditions         1
# 29       3            astar search - h pg levelsum         0

# %%
ax = complete.groupby('problem').sum().sort_values('complete', ascending=False)['complete'].plot(kind='bar')
ax.set_title('Figure 1: Completeness per problem (max = #searches = {})'.format(len(SEARCHES)))
ax.set_ylabel('Results with complete solution')
None

# %%
ax = complete.groupby('search').sum().sort_values('complete', ascending=False)['complete'].plot(kind='bar')
ax.set_title('Figure 2: Completeness per search (max = #problems = {})'.format(len(PROBLEMS)))
ax.set_ylabel('Results with complete solution')
None

# %% [markdown]
# ## Optimality

# %%
BEST = {'1': 6, '2': 9, '3': 12}

def is_optimal(row):
    return row['plan_length'] == BEST[row['problem']]


optimal = df[['problem', 'search', 'plan_length', 'plan']].copy()
optimal['optimal'] = optimal.apply(is_optimal, axis=1)

# %%
optimal.drop('plan', axis=1)
# Out:
#    problem                                  search  plan_length optimal
# 10       1    greedy best first graph search - h 1            6    True
# 1        1   depth first graph search - uninformed           20   False
# 15       1       breadth first search - uninformed            6    True
# 13       1        uniform cost search - uninformed            6    True
# 17       1   astar search - h ignore preconditions            6    True
# 12       1                      astar search - h 1            6    True
# 9        1       depth limited search - uninformed           50   False
# 2        1  breadth first tree search - uninformed            6    True
# 22       1       recursive best first search - h 1            6    True
# 7        1            astar search - h pg levelsum            6    True
# 8        2    greedy best first graph search - h 1           15   False
# 18       2   depth first graph search - uninformed          619   False
# 14       2       breadth first search - uninformed            9    True
# 6        2   astar search - h ignore preconditions            9    True
# 20       2        uniform cost search - uninformed            9    True
# 21       2                      astar search - h 1            9    True
# 11       2       depth limited search - uninformed           50   False
# 5        3   depth first graph search - uninformed          392   False
# 4        3       breadth first search - uninformed           12    True
# 16       3   astar search - h ignore preconditions           12    True
# 0        3    greedy best first graph search - h 1           24   False
# 19       3                      astar search - h 1           12    True
# 3        3        uniform cost search - uninformed           12    True

# %%
ax = optimal.groupby('problem').sum().sort_values('optimal', ascending=False)['optimal'].plot(kind='bar')
ax.set_title('Figure 3: Optimality per problem (max = #searches = {})'.format(len(SEARCHES)))
ax.set_ylabel('Results with optimal solution')
None

# %%
ax = optimal.groupby('search').sum().sort_values('optimal', ascending=False)['optimal'].plot(kind='bar')
ax.set_title('Figure 4: Optimality per search (max = #problems = {})'.format(len(PROBLEMS)))
ax.set_ylabel('Results with optimal solution')
None

# %%
# Out:
# Problem: 1 (#plans = 4)
#
# - Plan: 1
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
#
# - Plan: 2
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Fly(P1, SFO, JFK)
# Fly(P2, JFK, SFO)
# Unload(C1, P1, JFK)
# Unload(C2, P2, SFO)
#
# - Plan: 3
# Load(C2, P2, JFK)
# Load(C1, P1, SFO)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
# - Plan: 4
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
# Problem: 2 (#plans = 3)
#
# - Plan: 1
# Load(C3, P3, ATL)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
# - Plan: 2
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Load(C3, P3, ATL)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)
#
# - Plan: 3
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Load(C3, P3, ATL)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
#
# Problem: 3 (#plans = 3)
#
# - Plan: 1
# Load(C1, P1, SFO)
# Fly(P1, SFO, ATL)
# Load(C2, P2, JFK)
# Fly(P2, JFK, ORD)
# Load(C3, P1, ATL)
# Load(C4, P2, ORD)
# Fly(P2, ORD, SFO)
# Unload(C4, P2, SFO)
# Fly(P1, ATL, JFK)
# Unload(C3, P1, JFK)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)
#
# - Plan: 2
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Fly(P2, JFK, ORD)
# Load(C4, P2, ORD)
# Fly(P1, SFO, ATL)
# Load(C3, P1, ATL)
# Fly(P1, ATL, JFK)
# Unload(C1, P1, JFK)
# Unload(C3, P1, JFK)
# Fly(P2, ORD, SFO)
# Unload(C2, P2, SFO)
# Unload(C4, P2, SFO)
#
# - Plan: 3
# Load(C2, P2, JFK)
# Fly(P2, JFK, ORD)
# Load(C4, P2, ORD)
# Fly(P2, ORD, SFO)
# Unload(C4, P2, SFO)
# Load(C1, P1, SFO)
# Fly(P1, SFO, ATL)
# Load(C3, P1, ATL)
# Fly(P1, ATL, JFK)
# Unload(C3, P1, JFK)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)

# %% [markdown]
# ## Time complexity

# %%
ax = df.groupby('problem').mean()['runtime'].sort_values().plot(kind='bar')
ax.set_title('Figure 5: Runtime per problem')
ax.set_ylabel('Time in seconds')
None

# %%
ax = df.groupby('search').mean()['runtime'].sort_values().plot(kind='bar')
ax.set_title('Figure 6: Runtime per search')
ax.set_ylabel('Time in seconds')
None

# %%
ax = df[df['problem'] == '1'].sort_values('runtime').plot(x='search', y='runtime', kind='bar')
ax.set_title('Figure 7: Runtime of Problem 1')
ax.set_ylabel('Time in seconds')
None

# %%
ax = df[df['problem'] == '2'].sort_values('runtime').plot(x='search', y='runtime', kind='bar')
ax.set_title('Figure 8: Runtime of Problem 2')
ax.set_ylabel('Time in seconds')
None

# %%
ax = df[df['problem'] == '3'].sort_values('runtime').plot(x='search', y='runtime', kind='bar')
ax.set_title('Figure 9: time of Problem 3')
ax.set_ylabel('Time in seconds')
None

# %% [markdown]
# ## Space Complexity

# %%
ax = df.groupby('problem').mean()['new_nodes'].sort_values().plot(kind='bar')
ax.set_title('Figure 10: Node created per problem')
ax.set_ylabel('#nodes')
None

# %%
ax = df.groupby('search').mean()['new_nodes'].sort_values().plot(x='problem', y='new_nodes', kind='bar')
ax.set_title('Figure 11: Node created per problem')
ax.set_ylabel('#nodes')
None

# %%
ax = df[df['problem'] == '1'].sort_values('new_nodes').plot(x='search', y='new_nodes', kind='bar')
ax.set_title('Figure 12: Node created for Problem 1')
ax.set_ylabel('#nodes')
None

# %%
ax = df[df['problem'] == '2'].sort_values('new_nodes').plot(x='search', y='new_nodes', kind='bar')
ax.set_title('Figure 13: Node created for Problem 2')
ax.set_ylabel('#nodes')
None

# %%
ax = df[df['problem'] == '3'].sort_values('new_nodes').plot(x='search', y='new_nodes', kind='bar')
ax.set_title('Figure 14: Node created for Problem 1')
ax.set_ylabel('#nodes')
None

# %% [markdown]
# ## Summary

# %% [markdown]
# not complete:
# * astar search - h pg levelsum
# * recursive best first search - h 1
# * breadth first tree search - uninformed
# * depth limited search - uninformed
#
# not optimal:
# * depth first graph search - uninformed
# * depth limited search - uninformed
# * greedy best first graph search - h 1
#
# runtime > 400:
# * depth limited search - uninformed
# * uniform cost search - uninformed
# * astar search - h 1
#
# space complexity:
# * astar search - h 1
# * depth limited search - uninformed
# * breadth first search - uninformed
# * uniform cost search - uninformed
#
# heuristic: as explain in session, often good idea to simplify problem (e.g. preconditions)
#
# SEARCHES = [
#     # ["breadth_first_search", "uninformed"],
#     # ['breadth_first_tree_search', "uninformed"],
#     # ['depth_first_graph_search', "uninformed"],
#     # ['depth_limited_search', "uninformed"],
#     # ['uniform_cost_search', "uninformed"],
#     # ['recursive_best_first_search', 'h_1'],
#     # ['greedy_best_first_graph_search', 'h_1'],
#     # ['astar_search', 'h_1'],
#     ['astar_search', 'h_ignore_preconditions'],
#     # ['astar_search', 'h_pg_levelsum'],
# ]
#
# # same across problem (overall)

# %%
df[df['new_nodes'] > 100000]
# Out:
#    problem                             search             algorithm  \
# 11       2  depth limited search - uninformed  depth_limited_search
# 4        3  breadth first search - uninformed  breadth_first_search
# 19       3                 astar search - h 1          astar_search
# 3        3   uniform cost search - uninformed   uniform_cost_search
#
#      heuristic uninformed      runtime  plan_length  expansions  goal_tests  \
# 11  uninformed       True  1656.404348           50      222719     2053741
# 4   uninformed       True   213.483141           12       14663       18098
# 19         h_1      False   939.075264           12       18236       18238
# 3   uninformed       True   966.414331           12       18236       18238
#
#     new_nodes                                               plan
# 11    2054119  [Load(C1, P1, SFO), Load(C2, P2, JFK), Load(C3...
# 4      129631  [Load(C1, P1, SFO), Load(C2, P2, JFK), Fly(P2,...
# 19     159726  [Load(C1, P1, SFO), Fly(P1, SFO, ATL), Load(C2...
# 3      159726  [Load(C1, P1, SFO), Fly(P1, SFO, ATL), Load(C2...

# %% [markdown]
# # Conclusion

# %%
for problem, group in optimal[optimal['optimal']].groupby('problem'):
    
    plans = {'\n'.join(plan) for plan in group['plan']}
    print("Problem: {} (#plans = {})".format(problem, len(plans)))
    print()
    
    for i, plan in enumerate(plans, 1):
        print("- Plan: {}".format(i))
        print(plan)
        print()
# Out:
# Problem: 1 (#plans = 4)
#
# - Plan: 1
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
#
# - Plan: 2
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Fly(P1, SFO, JFK)
# Fly(P2, JFK, SFO)
# Unload(C1, P1, JFK)
# Unload(C2, P2, SFO)
#
# - Plan: 3
# Load(C2, P2, JFK)
# Load(C1, P1, SFO)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
# - Plan: 4
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
# Problem: 2 (#plans = 3)
#
# - Plan: 1
# Load(C3, P3, ATL)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
# - Plan: 2
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Load(C3, P3, ATL)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)
#
# - Plan: 3
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Load(C3, P3, ATL)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
#
# Problem: 3 (#plans = 3)
#
# - Plan: 1
# Load(C1, P1, SFO)
# Fly(P1, SFO, ATL)
# Load(C2, P2, JFK)
# Fly(P2, JFK, ORD)
# Load(C3, P1, ATL)
# Load(C4, P2, ORD)
# Fly(P2, ORD, SFO)
# Unload(C4, P2, SFO)
# Fly(P1, ATL, JFK)
# Unload(C3, P1, JFK)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)
#
# - Plan: 2
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Fly(P2, JFK, ORD)
# Load(C4, P2, ORD)
# Fly(P1, SFO, ATL)
# Load(C3, P1, ATL)
# Fly(P1, ATL, JFK)
# Unload(C1, P1, JFK)
# Unload(C3, P1, JFK)
# Fly(P2, ORD, SFO)
# Unload(C2, P2, SFO)
# Unload(C4, P2, SFO)
#
# - Plan: 3
# Load(C2, P2, JFK)
# Fly(P2, JFK, ORD)
# Load(C4, P2, ORD)
# Fly(P2, ORD, SFO)
# Unload(C4, P2, SFO)
# Load(C1, P1, SFO)
# Fly(P1, SFO, ATL)
# Load(C3, P1, ATL)
# Fly(P1, ATL, JFK)
# Unload(C3, P1, JFK)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)
